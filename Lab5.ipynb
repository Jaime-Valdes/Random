# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaime-Valdes/Random/blob/main/Lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

'''
position, velocity = np.loadtxt("Lab5.csv", skiprows = 5, usecols = (0,1), unpack = "True", dtype=float, delimiter=",", max_rows=36)
plt.scatter(position, velocity**2)
plt.xlabel('Position (m)')
plt.ylabel('Velocity Squared (m^2/s^2)')
a,b = np.polyfit(position, velocity**2, 1)
print(np.polyfit(position, velocity**2,1))
plt.plot(position, a*position+b)
'''

force, position = np.loadtxt("Lab5.csv", skiprows = 1, usecols = (3,4), unpack = "True", dtype=float, delimiter=",", max_rows=15)
plt.scatter(position, force)
plt.xlabel('Position (m)')
plt.ylabel('Force (N)')
a,b = np.polyfit(position, force, 1)
print(np.polyfit(position, force,1))
plt.plot(position, a*position+b)
work=0
for x in range(0,14):
  work += .5*(force[x]+force[x+1])*(position[x+1]-position[x])

print(f"Work = {work}")
# Out:
# [-4.40630952  1.00945714]
# Work = 0.10076474999999999
